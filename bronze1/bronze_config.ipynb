# %%
# ----------------------------
# Bronze Ingestion Configuration File
# ----------------------------

INGESTION_CONFIG = [
    {
        "source_path": "/Volumes/workspace/bronze/raw_sources/source_crm/cust_info.csv",
        "table_name": "cust_info",
        "database": "bronze",
        "format": "csv",
        "header": True,
        "infer_schema": True,
        "write_mode": "overwrite"
    },
    {
        "source_path": "/Volumes/workspace/bronze/raw_sources/source_crm/prd_info.csv",
        "table_name": "orders",
        "database": "bronze",
        "format": "csv",
        "header": True,
        "infer_schema": True,
        "write_mode": "overwrite"
    },
     {
        "source_path": "/Volumes/workspace/bronze/raw_sources/source_crm/sales_details.csv",
        "table_name": "cust_info",
        "database": "bronze",
        "format": "csv",
        "header": True,
        "infer_schema": True,
        "write_mode": "overwrite"
    },
      {
        "source_path": "/Volumes/workspace/bronze/raw_sources/source_erp/CUST_AZ12.csv",
        "table_name": "cust_info",
        "database": "bronze",
        "format": "csv",
        "header": True,
        "infer_schema": True,
        "write_mode": "overwrite"
    },
       {
        "source_path": "/Volumes/workspace/bronze/raw_sources/source_erp/LOC_A101.csv",
        "table_name": "cust_info",
        "database": "bronze",
        "format": "csv",
        "header": True,
        "infer_schema": True,
        "write_mode": "overwrite"
    },
        {
        "source_path": "/Volumes/workspace/bronze/raw_sources/source_erp/PX_CAT_G1V2.csv",
        "table_name": "cust_info",
        "database": "bronze",
        "format": "csv",
        "header": True,
        "infer_schema": True,
        "write_mode": "overwrite"
    }
]
